# %%
#!pip install bs4
#!pip install BeautifulSoup
#!pip install requests
#!pip install pandas

# %%
import bs4

# %%
from bs4 import BeautifulSoup  # HTML data structure

import pandas as pd

# %%
# URl to web scrap from.
# in this example we web scrap graphics cards from Newegg.com
 
url = "https://boston.craigslist.org/search/sof"
 
r = requests.get(url) 
print(r.content)
# Out:
# b'\xef\xbb\xbf<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  - craigslist</title>\n\n    <meta name="description" content="boston software/qa/dba/etc  - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://boston.craigslist.org/search/sof">\n    <link rel="alternate" type="application/rss+xml" href="https://boston.craigslist.org/search/sof?format=rss" title="RSS feed for craigslist | boston software/qa/dba/etc  - craigslist">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=1c8b9f6ba76c1ce6e888ec5c48118861">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "4";\nvar areaRegion = "MA";\nvar catAbb = "sof";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "jjj";\nvar sectionBase = "jjj";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n        }\n        pagemode = pagemode === \'mobile\' ? \'mobile\' : \'desktop\';\n        bodyClassList.push(pagemode);\n        if (C(\'hidesearch\') === \'1\' && pagemode !== \'mobile\') {\n            bodyClassList.push(\'hide-search\');\n        }\n        var width = window.innerWidth || document.documentElement.clientWidth;\n        if (width > 1000) { bodyClassList.push(\'w1024\'); }\n        if (typeof window.sectionBase !== \'undefined\') {\n            var mode = (decodeURIComponent(C(\'cl_tocmode\ ...

# %%
response = requests.get(url)

# %%
 response
# Out:
# <Response [200]>

# %%
data = response.text

# %%
data
# Out:
# '\ufeff<!DOCTYPE html>\n<html class="no-js"><head>\n    <title>boston software/qa/dba/etc  - craigslist</title>\n\n    <meta name="description" content="boston software/qa/dba/etc  - craigslist">\n    <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>\n    <link rel="canonical" href="https://boston.craigslist.org/search/sof">\n    <link rel="alternate" type="application/rss+xml" href="https://boston.craigslist.org/search/sof?format=rss" title="RSS feed for craigslist | boston software/qa/dba/etc  - craigslist">\n    <meta name="viewport" content="width=device-width,initial-scale=1">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/cl.css?v=1c8b9f6ba76c1ce6e888ec5c48118861">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/search.css?v=bc035cbbc3978b0ec9df93944cdf349b">\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/jquery-ui-clcustom.css?v=3b05ddffb7c7f5b62066deff2dda9339">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/leaflet.css?v=33e3dd14c7deed955c83b6927c5e1f07">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/MarkerCluster.css?v=9bea97021e746649c6837e95dd9723e8">\n<link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps.css?v=d8743547c59d5ad31d4d7294c7e2f7f2">\n<!--[if IE]>\n    <link type="text/css" rel="stylesheet" media="all" href="//www.craigslist.org/styles/tocsmaps-ie.css?v=b21742b2ebe243963373e956ea115db0">\n<![endif]-->\n\n    \n        <script type="text/javascript"><!--\nvar areaCountry = "US";\nvar areaID = "4";\nvar areaRegion = "MA";\nvar catAbb = "sof";\nvar countOfTotalText = "image {count} of {total}";\nvar currencySymbol = "&#x0024;";\nvar defaultView = "list";\nvar expiredFavIDs = null;\nvar imageConfig = {"1":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]},"0":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450"]},"2":{"hostname":"https://images.craigslist.org","sizes":["50x50c","300x300","600x450","1200x900"]}};\nvar lessInfoText = "less info";\nvar maptileBaseUrl = "//map{s}.craigslist.org/t09/{z}/{x}/{y}.png";\nvar maxResults = 3000;\nvar noImageText = "no image";\nvar pID = null;\nvar postalLat = null;\nvar postalLon = null;\nvar purveyorCategories = null;\nvar searchDistance = null;\nvar sectionAbb = "jjj";\nvar sectionBase = "jjj";\nvar showInfoText = "show info";\nvar showMapTabs = 1;\nvar showingBanished = 0;\nvar showingFavorites = 0;\nvar starHint = "save this post in your favorites list";\nvar subarea = null;\nvar zoomToPosting = null;\n--></script>\n    \n</head>\n<body class="search has-map">\n    <script type="text/javascript"><!--\n    function C(k){return(document.cookie.match(\'(^|; )\'+k+\'=([^;]*)\')||0)[2]}\n    var pagetype, pagemode;\n    (function(){\n        var h = document.documentElement;\n        h.className = h.className.replace(\'no-js\', \'js\');\n        var b = document.body;\n        var bodyClassList = b.className.split(/\\s+/);;\n        pagetype = bodyClassList[0]; // dangerous assumption\n        var fmt = C(\'cl_fmt\');\n        if ( fmt === \'regular\' || fmt === \'mobile\' ) {\n            pagemode = fmt;\n        } else if (screen.width <= 480) {\n            pagemode = \'mobile\';\n        } else {\n            pagemode = \'regular\';\n        }\n        pagemode = pagemode === \'mobile\' ? \'mobile\' : \'desktop\';\n        bodyClassList.push(pagemode);\n        if (C(\'hidesearch\') === \'1\' && pagemode !== \'mobile\') {\n            bodyClassList.push(\'hide-search\');\n        }\n        var width = window.innerWidth || document.documentElement.clientWidth;\n        if (width > 1000) { bodyClassList.push(\'w1024\'); }\n        if (typeof window.sectionBase !== \'undefined\') {\n            var mode = (decodeURIComponent(C(\'cl_tocmode\') || \ ...

# %%
soup = BeautifulSoup (data, 'html.parser')

# %%
tags = soup.find_all('a')

# %%
for tag in tags:
  print(tag.get('herf'))

# %%
for tag in tags:
  print(tag.text)
# Out:
# CL
# boston
# post
# account
# 0 favorites
#
#
# 0
#  hidden
#
# CL
# save search
# software/qa/dba/etc
# reset
# newest
# <<
# < prev
# next >
#
# Azure Cloud Systems Engineer
#
# restore
# restore this posting
#
#
# Wanted: Magento Frontend Magician
#
# restore
# restore this posting
#
#
# Senior Access Database Developer
#
# restore
# restore this posting
#
#
# eCommerce Quality Assurance Professional
#
# restore
# restore this posting
#
#
#
# Become Cloud Architect and earn $90K+ in as little as 7 months
#
# restore
# restore this posting
#
#
# Jr. Software Developer - OPT & CPT
#
# restore
# restore this posting
#
#
# HTML/Angular 8/Business Dashboard Programmer
#
# restore
# restore this posting
#
#
# Data Science Fellowship
#
# restore
# restore this posting
#
#
# Job Referrals Available for Amazing Tech/Software Positions
#
# restore
# restore this posting
#
#
# Software Engineering Fellowship
#
# restore
# restore this posting
#
#
# Manual Mobile QA Tester (Native Apps - local candidates only)
#
# restore
# restore this posting
#
#
# Software Development Engineer I
#
# restore
# restore this posting
#
#
# Jr. Software Developer - OPT & CPT
#
# restore
# restore this posting
#
#
#
# Senior Software Developer (Remote Available)
#
# restore
# restore this posting
#
#
# Data Science Fellowship
#
# restore
# restore this posting
#
#
# Software Engineering Fellowship
#
# restore
# restore this posting
#
#
# Platform Engineer
#
# restore
# restore this posting
#
#
# Senior Magento Frontend Developer
#
# restore
# restore this posting
#
#
# Facilities Assistant
#
# restore
# restore this posting
#
#
# DevOps Engineer
#
# restore
# restore this posting
#
#
# Full Stack Software Engineer
#
# restore
# restore this posting
#
#
# C# .NET Software Developer
#
# restore
# restore this posting
#
#
# Jr. Software Developer - OPT & CPT
#
# restore
# restore this posting
#
#
# Senior Magento 2 Backend Developer
#
# restore
# restore this posting
#
#
# Data Science Fellowship
#
# restore
# restore this posting
#
#
# Software Engineering Fellowship
#
# restore
# restore this posting
#
#
# SQL Server Developer/Analyst
#
# restore
# restore this posting
#
#
# Senior Software Engineer
#
# restore
# restore this posting
#
#
# Full Stack Engineer (multiple)
#
# restore
# restore this posting
#
#
# Senior Software Engineer - MIT spinoff
#
# restore
# restore this posting
#
#
# Facilities Assistant
#
# restore
# restore this posting
#
#
# Senior Software Engineer
#
# restore
# restore this posting
#
#
#
# Become Cloud Architect and earn $90K+ in as little as 7 months
#
# restore
# restore this posting
#
#
# Software Development Engineer I
#
# restore
# restore this posting
#
#
# Jr. Software Developer - OPT & CPT
#
# restore
# restore this posting
#
#
#
# Senior Software Developer (Remote Available)
#
# restore
# restore this posting
#
#
# Azure .net Software Engineer
#
# restore
# restore this posting
#
#
# Data Science Fellowship
#
# restore
# restore this posting
#
#
# Software Engineering Fellowship
#
# restore
# restore this posting
#
#
#
# Data Engineer
#
# restore
# restore this posting
#
#
# Jr. Software Developer - OPT & CPT
#
# restore
# restore this posting
#
#
# Lead Engineer - Full Stack
#
# restore
# restore this posting
#
#
# Entry Level Web Developer
#
# restore
# restore this posting
#
#
# Python Software Engineer
#
# restore
# restore this posting
#
#
# Node.js Software Engineer
#
# restore
# restore this posting
#
# ^ back to top
# ^ back to top
# <<
# < prev
# next >
# RSS
# (?)
# help
# safety
# privacy
# feedback
# cl jobs
# terms
# about

# %% [markdown]
# #Show Title & Address

# %%
titles =soup.find_all("a",{"class":"result-title"})

# %%
for title in titles:
  print(title.text)
# Out:
# Data Science Fellowship
# Job Referrals Available for Amazing Tech/Software Positions
# Software Engineering Fellowship
# Manual Mobile QA Tester (Native Apps - local candidates only)
# Software Development Engineer I
# Jr. Software Developer - OPT & CPT
# Senior Software Developer (Remote Available)
# Data Science Fellowship
# Software Engineering Fellowship
# Platform Engineer
# Senior Magento Frontend Developer
# Full stack / Django Python developer
# Facilities Assistant
# DevOps Engineer
# Full Stack Software Engineer
# C# .NET Software Developer
# Jr. Software Developer - OPT & CPT
# Senior Magento 2 Backend Developer
# Data Science Fellowship
# Software Engineering Fellowship
# SQL Server Developer/Analyst
# Senior Software Engineer
# Full Stack Engineer (multiple)
# Senior Software Engineer - MIT spinoff
# Facilities Assistant
# Senior Software Engineer
# Become Cloud Architect and earn $90K+ in as little as 7 months
# Software Development Engineer I
# Jr. Software Developer - OPT & CPT
# Senior Software Developer (Remote Available)
# Azure .net Software Engineer
# Data Science Fellowship
# Software Engineering Fellowship
# Data Engineer
# Jr. Software Developer - OPT & CPT
# Lead Engineer - Full Stack
# Data Science Fellowship
# Software Engineering Fellowship
# Entry Level Web Developer
# Software and Data Engineer (full-stack)
# Python Software Engineer
# Node.js Software Engineer

# %%
 adresses= soup.find_all("span",{"class":"result-hood"})

# %%
for adress in adresses:
    print(adress.text)
# Out:
#  (Boston)
#  (Waltham, MA)
#  (Virginia Beach)
#  (boston: boston/cambridge/brookline)
#  (Boston)
#  (Medford)
#  (Cambridge, MA)
#  (Framingham)
#  (Woburn, MA)
#  (North Station, Boston)
#  (Boston / WFH)
#  (Framingham)
#  (Medford)
#  (boston: boston/cambridge/brookline)
#  (Waltham, MA)
#  (Virginia Beach)
#  (Jupiter)
#  (Boston)

# %% [markdown]
# #show job info

# %%
jobs = soup.find_all('p',{'class':'result-info'})

# %%
for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time',{'class':'result-date'}).text
    link = job.find('a',{'class':'result-title'}).get('href')
    print('Job Title:', title, '\nLocation', location, '\nDate:', date, '\nLink:', link, '\n---')
# Out:
# Job Title: Data Science Fellowship
# Location N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7024696124.html
# ---
# Job Title: Job Referrals Available for Amazing Tech/Software Positions
# Location N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-job-referrals-available-for/7024692015.html
# ---
# Job Title: Software Engineering Fellowship
# Location N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7024690835.html
# ---
# Job Title: Manual Mobile QA Tester (Native Apps - local candidates only)
# Location Boston
# Date: Nov 18
# Link: https://boston.craigslist.org/gbs/sof/d/boston-manual-mobile-qa-tester-native/7022545596.html
# ---
# Job Title: Software Development Engineer I
# Location Waltham, MA
# Date: Nov 18
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/7022471531.html
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location N/A
# Date: Nov 18
# Link: https://boston.craigslist.org/sob/sof/d/boston-jr-software-developer-opt-cpt/7022322359.html
# ---
# Job Title: Senior Software Developer (Remote Available)
# Location Virginia Beach
# Date: Nov 15
# Link: https://boston.craigslist.org/gbs/sof/d/virginia-beach-senior-software/7020506451.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7020245669.html
# ---
# Job Title: Software Engineering Fellowship
# Location N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7020241473.html
# ---
# Job Title: Platform Engineer
# Location boston: boston/cambridge/brookline
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-platform-engineer/7020204286.html
# ---
# Job Title: Senior Magento Frontend Developer
# Location N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-magento-frontend-developer/7019962471.html
# ---
# Job Title: Full stack / Django Python developer
# Location Boston
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-stack-django-python/7019788209.html
# ---
# Job Title: Facilities Assistant
# Location Medford
# Date: Nov 13
# Link: https://boston.craigslist.org/gbs/sof/d/medford-facilities-assistant/7019155881.html
# ---
# Job Title: DevOps Engineer
# Location N/A
# Date: Nov 12
# Link: https://boston.craigslist.org/gbs/sof/d/boston-devops-engineer/7018950123.html
# ---
# Job Title: Full Stack Software Engineer
# Location Cambridge, MA
# Date: Nov 12
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-software-engineer/7018868025.html
# ---
# Job Title: C# .NET Software Developer
# Location Framingham
# Date: Nov 12
# Link: https://boston.craigslist.org/bmw/sof/d/framingham-net-software-developer/7018509536.html
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location N/A
# Date: Nov 11
# Link: https://boston.craigslist.org/nwb/sof/d/boston-jr-software-developer-opt-cpt/7017837770.html
# ---
# Job Title: Senior Magento 2 Backend Developer
# Location N/A
# Date: Nov  9
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-magento-2-backend/7016890026.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: Nov  8
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7016362963.html
# ---
# Job Title: Software Engineering Fellowship
# Location N/A
# Date: Nov  8
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7016355028.html
# ---
# Job Title: SQL Server Developer/Analyst
# Location Woburn, MA
# Date: Nov  8
# Link: https://boston.craigslist.org/bmw/sof/d/woburn-sql-server-developer-analyst/7016111801.html
# ---
# Job Title: Senior Software Engineer
# Location North Station, Boston
# Date: Nov  7
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer/7015660369.html
# ---
# Job Title: Full Stack Engineer (multiple)
# Location Boston / WFH
# Date: Nov  7
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-stack-engineer-multiple/7015643716.html
# ---
# Job Title: Senior Software Engineer - MIT spinoff
# Location Framingham
# Date: Nov  7
# Link: https://boston.craigslist.org/bmw/sof/d/framingham-senior-software-engineer-mit/7015639042.html
# ---
# Job Title: Facilities Assistant
# Location Medford
# Date: Nov  7
# Link: https://boston.craigslist.org/gbs/sof/d/medford-facilities-assistant/7015520363.html
# ---
# Job Title: Senior Software Engineer
# Location boston: boston/cambridge/brookline
# Date: Nov  7
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer/7015425065.html
# ---
# Job Title: Become Cloud Architect and earn $90K+ in as little as 7 months
# Location N/A
# Date: Nov  4
# Link: https://boston.craigslist.org/gbs/sof/d/waltham-become-cloud-architect-and-earn/7013802366.html
# ---
# Job Title: Software Development Engineer I
# Location Waltham, MA
# Date: Nov  4
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/7013365567.html
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location N/A
# Date: Nov  4
# Link: https://boston.craigslist.org/bmw/sof/d/boston-jr-software-developer-opt-cpt/7013257955.html
# ---
# Job Title: Senior Software Developer (Remote Available)
# Location Virginia Beach
# Date: Nov  1
# Link: https://boston.craigslist.org/gbs/sof/d/virginia-beach-senior-software/7011720555.html
# ---
# Job Title: Azure .net Software Engineer
# Location N/A
# Date: Nov  1
# Link: https://boston.craigslist.org/nos/sof/d/danvers-azure-net-software-engineer/7011354309.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: Oct 31
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7011086262.html
# ---
# Job Title: Software Engineering Fellowship
# Location N/A
# Date: Oct 31
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7011080713.html
# ---
# Job Title: Data Engineer
# Location Jupiter
# Date: Oct 29
# Link: https://boston.craigslist.org/gbs/sof/d/jupiter-data-engineer/7009376120.html
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location N/A
# Date: Oct 28
# Link: https://boston.craigslist.org/gbs/sof/d/roxbury-crossing-jr-software-developer/7008767810.html
# ---
# Job Title: Lead Engineer - Full Stack
# Location Boston
# Date: Oct 28
# Link: https://boston.craigslist.org/gbs/sof/d/boston-lead-engineer-full-stack/7008676043.html
# ---
# Job Title: Data Science Fellowship
# Location N/A
# Date: Oct 24
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7006422188.html
# ---
# Job Title: Software Engineering Fellowship
# Location N/A
# Date: Oct 24
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7006415440.html
# ---
# Job Title: Entry Level Web Developer
# Location N/A
# Date: Nov 19
# Link: https://providence.craigslist.org/sof/d/newport-entry-level-web-developer/7023396802.html
# ---
# Job Title: Software and Data Engineer (full-stack)
# Location N/A
# Date: Oct 24
# Link: https://providence.craigslist.org/sof/d/north-kingstown-software-and-data/7006516880.html
# ---
# Job Title: Python Software Engineer
# Location N/A
# Date: Nov  8
# Link: https://hartford.craigslist.org/sof/d/hartford-python-software-engineer/7016071955.html
# ---
# Job Title: Node.js Software Engineer
# Location N/A
# Date: Nov  8
# Link: https://hartford.craigslist.org/sof/d/hartford-nodejs-software-engineer/7016059857.html
# ---

# %% [markdown]
# #Show all info of job

# %%
jobs = soup.find_all('p',{'class':'result-info'})

# %%
for job in jobs:
    title = job.find('a',{'class':'result-title'}).text
    location_tag = job.find('span',{'class':'result-hood'})
    location = location_tag.text[2:-1] if location_tag else "N/A"
    date = job.find('time', {'class': 'result-date'}).text
    link = job.find('a', {'class': 'result-title'}).get('href')
    job_response = requests.get(link)
    job_data = job_response.text
    job_soup = BeautifulSoup(job_data, 'html.parser')
    job_description = job_soup.find('section',{'id':'postingbody'}).text
    job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
    job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
    
    print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
# Out:
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7024696124.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Job Referrals Available for Amazing Tech/Software Positions
# Location: N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-job-referrals-available-for/7024692015.html
#
# compensation: Determined by the job
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# The adage of "It's who you know, not what you know" really is difficult to reconcile when you feel like you have no network to get to your next career step.
#
# Over the past 12 years, I heard this advice a lot as I moved around from city to city—both in the US and abroad. With every move, I had to rebuild my network, and it was *really* difficult each time.
#
# If you're someone who's ever experienced a life transition, like a career change, having a child, or deciding to return to work after taking an extended leave, then this story is probably all too familiar.
#
# If you're a woman, minority, or person with a non-traditional background which, when combined, represents the majority of the U.S. population, then it's *really* difficult to make any change because people already have these preconceived notions about you.
#
# It's not an excuse, but an acknowledgment that biases are our reality.
#
# Our reality is harsh on the job search. And we all could use help in fending off common biases in our job search so we can overcome the challenges we face in our transitions.
#
# That's why we built JobFit - to help people in transition broaden the "who you know," so you can show them your "what you know." We primarily assist people who are interested in transitioning to a new city for their next career step.
#
# Whether you want to move for family, a change of scenery, or better opportunities, our goal is to help people find job referrals in cities where they want to work.
#
# Find any job referral for any specific job to any particular company.
#
# Our process of applying for job referrals is simple.
#
# 1. Find a company where you want a job referral.
# 2. Anonymously answer a few questions on what interested you about the company. Anonymity is to protect you from bias against your location, among other hiring bias.
# 3. A non-recruiter employee at the company will review your answers. If the employee likes your responses, they gain access to your name and resume for the job referral.
#
#
# Here are some job referrals you can directly start connecting to right away:
#
# For a job referral to DroneDeploy - https://formyreferral.getjobfit.com/MXBH7tBNl1?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=dronedeploy%2C%20v1&utm_content=sponsor_link
#
# For a job referral to Intel - https://formyreferral.getjobfit.com/Db5XfR1HKZ?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=intel%2C%20v1&utm_content=sponsor_link
#
# For a job referral to Accenture - https://formyreferral.getjobfit.com/0cPmVsfLb1?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=accenture%2C%20v1&utm_content=sponsor_link
#
# For a job referral to Google - https://formyreferral.getjobfit.com/7pFy7DahVW?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=google%2C%20v1&utm_content=sponsor_link
#
#
# We have resources to get you more job referrals to anywhere you want. You can explore other jobs in the remaining 70,000 companies in our network. Don't let your location limit your goals. You can even find job referrals for remote jobs if you wish.
#
#
# Check out JobFit for more details.
#
# https://getjobfit.com/?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=v1
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7024690835.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: Manual Mobile QA Tester (Native Apps - local candidates only)
# Location: Boston
# Date: Nov 18
# Link: https://boston.craigslist.org/gbs/sof/d/boston-manual-mobile-qa-tester-native/7022545596.html
#
# compensation: Competitive
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# LOCAL CANDIDATES ONLY – MUST HAVE MOBILE TESTING EXPERIENCE
#
# Our client, a leading digital marketing agency in Boston, is looking to hire a QA Engineer with mobile application testing experience ASAP.  This is a 6 month contract assignment to start with potential for extensions, or even a temp to hire for the right person.
#
# Take proactive, expert ownership of Quality Assurance role on client and internal projects
# Author test plans, test cases, and/or test scripts required to validate solutions
# Partner closely with the development teams to replicate and resolve issues
# Work closely across all capabilities (e.g. Technology, Project Management, User Experience/Creative, etc.) to ensure that all quality assurance requirements are defined and properly documented
# Assist in reviewing and refining existing QA process, controls, and best practices
# Act as a strong advocate for quality and share QA knowledge to other team members within the company
# Ensure all projects meet both functional and non-functional requirements and map to QA test cases
# Assist QA Leadership in training and mentoring other QA staff members on QA best practices and techniques
#
# Qualities and Experience for the Mobile QA Tester:
#
# Expertise in various forms of software testing: functional and non-functional testing – regression testing, performance testing, etc.
# Experience testing native mobile applications for iOS and Android is a FIRM REQUIREMENT.
# Experience in cross device/cross OS version testing of native mobile applications
# Experience testing native mobile applications under degraded/slow/no network conditions
# Responsive Design testing experience
# Ability to understand business needs and translate them into test cases and test scenarios
# Demonstrated ability to work collaboratively with teams and clients
# Extensive understanding in QA process (Agile and Waterfall), tools, and approaches
# Experience with JIRA, Agilecraft, or similar bug and issue tracking solutions
# Experience with Mobile Web testing and simulator/emulation tools
# Knowledge of Selenium test automation a strong plus
# Experience with Blazemeter / JMeter/load testing tools, and performance testing tools a plus
# Experience with testing beyond functional (e.g. Web Accessibility, security, etc.) a plus
#
# Education for the Mobile QA Engineer:
#
# 3-5 or more years of Software Quality Assurance experience
# BS/MS in Computer Science or equivalent preferred
# ---
# Job Title: Software Development Engineer I
# Location: Waltham, MA
# Date: Nov 18
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/7022471531.html
#
# compensation: DOE + benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Yardi Systems is currently seeking a full time, highly motivated Software Development Engineer I to join their growing team in Waltham, MA!
#
# In response to continued demand for our services, Yardi Resident Screening is looking for a Software Development Engineer to join our team in Waltham, MA.  Reporting to the Director of Information Technology, you will be a core member of our software development team.   You will leverage your analytical problem solving skills to support and enhance our Linux and web based systems utilizing your solid Java programming skills, database skills and knowledge of open source tools.
# Responsibilities
#
# Perform development tasks including programming, unit testing, and database design.
# Contribute to integration and general system regression testing.
# Participate on installs and provide on-going production support.
#
# Requirements
#
# BS or MS Degree in Computer Science, Systems Engineering or related field.
# 2+ years’ experience in Software Development.
# Interest to contribute to systems architectural improvements.
# Excellent verbal and written communication skills as well as being a team player.
# 1+ years of experience working on multi-tiered web application architecture.
# 1+ years supporting and developing production systems using Linux, Java, XML , JAXB, JSP, JavaScript, JQuery, Tomcat, web services.
# Good relational databases skill using PostgreSQL or Oracle with JDBC, SQL, Hibernate.
# Experience with Eclipse IDE and use of source repositories.
# Experience with 3rd Party API Integration (web services,…)
# Solid object oriented skills and conceptual understanding.
# Understanding of the product development lifecycle through design, development, testing, rollout, and support.
# Ability to understand and document business requirements.
# Ability to work with multi-site and off-shore development teams.
# Availability for occasional night, weekend, and holiday work assignments.
#
#
# PLEASE APPLY TO: https://careers.yardi.com/openings/job-posting/RS19413744/
#
# Yardi Systems is a successful independent software company with a proven history of growth and market leadership in the multi-billion dollar global commercial real estate industry. We employ talented, motivated and innovative people that are focused on delivering superior solutions to our clients and are passionate about working with other highly skilled professionals in team environments.
#
# If you are seeking an opportunity to join a winning team, work with the latest Microsoft technologies and develop your career, then Yardi Systems is the place for you. We have a pleasant and casual work environment, competitive salaries, and a comprehensive benefits package. Our corporate culture stresses integrity, respect, trust, responsibility, and fun.
#
# EOE Race/Gender/Disability/Vets
#
#
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location: N/A
# Date: Nov 18
# Link: https://boston.craigslist.org/sob/sof/d/boston-jr-software-developer-opt-cpt/7022322359.html
#
# compensation: 60k-70k
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Jr. Software Developer - OPT & CPT
# © craigslist - Map data © OpenStreetMap
# (google map)
#
# compensation: 60k-70k
# employment type: full-time
# Training and placement in 6 weeks!
# - 600 consultants placed at fortune 500 clients
# - Based out of Washington DC Metro
# - Requires basic programming skills in one or more (C/C++/Java/.NET)
# - Training and Placement in Java, .NET, iOS, Android, UI, QA, Mobile Testing
# - Training geared towards entry-level developers and recent grads
# - Relocation and accommodation
# - OPT/CPT welcome. H1B/GC sponsorship
#
# ****************************************
# Email your resumes today along with a basic overview of your technical/programming skills and your current work authorization (i.e. F1, H1B, GC, US Citizen).
# ****************************************
# ---
# Job Title: Senior Software Developer (Remote Available)
# Location: Virginia Beach
# Date: Nov 15
# Link: https://boston.craigslist.org/gbs/sof/d/virginia-beach-senior-software/7020506451.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our Development Team is looking for a Senior Software Developer to join them in shaping our company by creating, enhancing, and maintaining PHP based internal and external products. As part of the team, you will work within the LAMP stack in an Agile based environment to help ensure our products provide a great user experience and significant value to the customer.
#
# This role can be filled remotely or from one of our offices.
#
# What You’ll Do:
#
# Develop structured application/interface code, new program documentation, operations documentation and user guides in a casual, flexible environment
# Communicate with end users and internal customers to develop, debug, and test application software for accuracy, integrity, interoperability and completeness.
# Produce reliable, testable software applications using a disciplined development approach
# Utilize your advanced PHP and MySQL skills to create back end tooling
# Collaborate with stakeholders and leadership to prioritize and implement features
# Develop new functionality and applications on cross functional Agile project teams
# Review and test team member’s code to ensure the software meets our high quality standards and operates efficiently
# Build your skill set in a collaborative, team-focused environment
#
# Ideal Candidates Have:
#
# 5-8 years progressive development experience, primarily focused on web applications, back end automation
# Bachelor’s Degree in Computer Science and/or equivalent experience
# Extensive background in LAMP development
# Ability to move back and forth between Front End and API Back End work
# Experience with UI/UX fundamentals
# Advanced experience with  PHP and MySQL
# Advanced understanding of object oriented principles
# Talent for building user interfaces using JS, jQuery, HTML, CSS and AJAX
# Background in refactoring/verifying systems through automated testing and test-driven development in large scale systems
# Experience with software deployment, Continuous Integration (CI), and Continuous Delivery (CD) concepts, applications, and tools highly preferred
# Basic knowledge of the Linux/Unix command-line
# Experience with MVC frameworks required, Zend Framework preferred
# Advanced JavaScript experience and mid-level or better experience with one or more of the common frameworks like React or Angular is a plus
# Experience in the WordPress ecosystem building or modifying plugins preferred
# A passion for creating a high quality user experience
# Experience with development of automated customer processes and systems
#
# What You’ll Get:
#
# Profit sharing twice a year
# Medical, dental, vision, disability, life insurance, and 401K plans
# Casual work environment and relaxed dress code
# Free weekly lunch and snacks
# Tuition and certification reimbursement
# Opportunities for advancement after 90 days
# To be a part of an incredible team in a collaborative environment
#
# Location:
#
# Denver, CO
# Virginia Beach, VA
# Remote
#
# See what it's like working at InMotion and all the great perks that come with it. You can also check out our products here.
#
# Apply Here...
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7020245669.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7020241473.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: Platform Engineer
# Location: boston: boston/cambridge/brookline
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-platform-engineer/7020204286.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Platform Engineer/Backend (Boston, MA)                         compensation: $150KA Boston based Cloud Security Platform provider that is building the next frontier of software security,  seeks to hire a full-time Platform Engineer to join its team in downtown Boston!YOUR CAREER GOALSYou want to build highly scalable and dependent software solutions within the ever growing cloud security space. You enjoy working up and down the platform stack, from datastores to REST APIs. You enjoy exploring new ways to efficiently ingest, process, store, and leverage the vast amount of data this firm captures. You want to have a vocal role on a team looking to constantly improve their product.YOUR AMAZING QUALITIESYou're passionate about building and scaling high-volume, highly available SaaS solutions. You enjoy API design for internal and external customers. . You recognize process or programming inefficiencies and can recommend improvements in a heartbeat. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least two years of professional experience in the full lifecycle development of software applications using:Node.jsScalaPythonElasticSearchRabbitMQCassandraAWSYou must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:Scale Challenges that allow you to directly influence and build software that is processing billions of events per dayA cohesive engineering team where software and infrastructure engineers work side-by-side during release cycles, resolving bottlenecks, and improving reliability and scalabilityComprehensive healthcare coverage, including HMO/PPO plans, dental, vision, life, short-term and long-term disabilityGenerous PTO (3 weeks!)401(k) planEquity GrantsCommuter/Transit expense subsidyCompany supplied treats and snacksAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Senior Magento Frontend Developer
# Location: N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-magento-frontend-developer/7019962471.html
#
# compensation: Negotiable
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# We’re looking for a highly skilled and motivated Senior Magento Frontend Developer with at least 3 years of experience. We want you if you’re a self-motivated, detail oriented, team-player with strong communication skills. You will be responsible for finding solutions to complex problems related to Magento sites, and providing updates for Magento software and Magento based sites.
#
# Required Skills:
# 3+ years experience as a Magento front-end developer
# CSS / HTML / JS and JQuery
# LESS, SASS & COMPASS
# Experience converting PSDs into HTML & CSS
# Expertise with slicing designs into the Magento templating system
# Pride in your ability to use Magento best practices with your front-end code
# Demonstratable History of magento UI
# Graphic design experience is an asset
# Excellent written and verbal communication
#
# Please Include Resume as an Attachment
#
#
# ---
# Job Title: Full stack / Django Python developer
# Location: Boston
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-stack-django-python/7019788209.html
#
# compensation: Hourly rate / TBD
#
# employment type: employee's choice
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
#
#
#
# Hello,
#
# Alyx Health is a startup developing a solution for nurse practices. Alyx Health is looking for 2 developers with a deep knowledge of Django.
#
# The company currently works in Downtown Boston.
# We're looking for a good mix of professional skills with a capability to work within a team and have the desire to learn the needs of the industry.
#
# Our preferences are for developers who can be in our office in Boston.
#
# Location: Boston area
#
# Main qualifications:
# - Python (3)
# - Django
# - AWS
# - MySQL
# - Javascript / JQuery
# - CSS
# - Git/Github
# - REST API
#
# In addition, knowledge with JS frameworks and mobile development will be a plus.
#
# Please email your resume and indicate any experience relevant to the position.
#
# Start - Nov. 2019.
#
# -------------------------------------------------------------------------
# Python, Django, REST API, CSS, Javascript, JQuery, AWS, Database, MySQL, JSON, Healthcare
# ---
# Job Title: Facilities Assistant
# Location: Medford
# Date: Nov 13
# Link: https://boston.craigslist.org/gbs/sof/d/medford-facilities-assistant/7019155881.html
#
# compensation: Commensurate with Experience.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job Overview:
# ---
# Job Title: DevOps Engineer
# Location: N/A
# Date: Nov 12
# Link: https://boston.craigslist.org/gbs/sof/d/boston-devops-engineer/7018950123.html
#
# compensation: Based on Experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Job Title: DevOps Engineer
# Location: Boston, Massachusetts
#
# A digital health company providing Care Pathway Management solutions is looking for a DevOps Engineer to maintain and develop its world-class, web-based, healthcare platform.
#
# Key Responsibilities:
#
# ● Working within the Technical Operations team on a day-to-day basis, supporting requests and requirements for new and existing infrastructure/software
# ● Assist in developing the companies infrastructure using automated tools, writing or employing
# routines to support/manage the platform
# ● Working with the broader business in order to solve customer issues such as integrations
# requirements
#
# Essential Experience:
#
# A 4-year degree in Computer Science or similar experience
# Strong background in Linux/Unix Administration
# Excellent LEMP (Linux, Nginx, MySQL, PHP) administration experience
# Expert understanding of cloud-based Web architecture
# Good knowledge of AWS
# Experience of systems automation technologies (e.g. Ansible, Terraform)
# Fluent in SQL, including data migration tasks
# Strong experience with bash shell and other scripting languages
# Familiarity with database administration and tools, such as stored procedures and optimization
#
# Bonuses:
#
# Experience in a PCI-DSS or ISO 27001-compliant environment
# Understanding of other languages such as Python, Ruby
# Experience with systems integration, healthcare specifically (e.g. HL7, MirthConnect, DICOM)
# Icinga, New Relic, Git, Jenkins, and varied open source technologies.
# PHP (Symfony) development skills
#
# ---
# Job Title: Full Stack Software Engineer
# Location: Cambridge, MA
# Date: Nov 12
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-software-engineer/7018868025.html
#
# compensation: Commensurate with experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Apply here: https://superpedestrian.applytojob.com/apply/u89CFqFga2/Full-Stack-Software-Engineer?source=Craigslist
#
# Superpedestrian brings together a team of extraordinary people for one vision: transforming urban mobility. To work with us, you should possess a strong desire to change the way people everywhere move about cities. We're revolutionizing personal transit for a sustainable future. Superpedestrian is an equal opportunity employer, with women and minorities strongly encouraged to apply. We care about your skills and your character. If we think there's a good fit, we will get in touch. So please, no phone calls or recruiters.
#
# The software team at Superpedestrian works on our scooter and electric bike fleet management and Vehicle Intelligence system. This includes backend and APIs to support the rich data we collect, communication and security for IoT, manufacturing integration, research and support tools, mobile SDKs and much more!  We’re a tight knit, industrious bunch and we are seeking a Senior Software Engineer to join the team. The ideal candidate has strong skills in backend development, optimizing algorithms and database structures, but can contribute on multiple levels.
#
# There are currently several opportunities open in the software team, and we are looking for candidates at different stages of their career. Don't hesitate to apply if you only meet some of the preferred qualifications or if you feel you're overqualified. This is a position where you will have the opportunity to shape your responsibilities based on your skills and interests.
#
#
# What you'll do:
#  - Create multiple database-backed API backends
#  - Collaborate with cross-functional teams to define, design and ship new features
#  - Contribute across the stack on developing web applications, data layers, and back end services
#  - Unit-test code for robustness, including edge cases, usability and general reliability
#  - Work on improving application performance and bug fixes
#  - Continuously discover, evaluate, and implement new technologies to maximize development efficiency and application performance
#  - Participate in cross-team peer code reviews
#  - Participate in Agile Scrum sprint and release planning
#
# What we're looking for:
#  - 3+ years of industry experience building scalable backend services
#  - Significant experience with Python
#  - Experience with Django, Rails, Node or similar web framework
#  - Undergraduate degree in computer science or related field
#  - Experience with RESTful web services, JSON
#  - Working knowledge of database systems
# ---
# Job Title: C# .NET Software Developer
# Location: Framingham
# Date: Nov 12
# Link: https://boston.craigslist.org/bmw/sof/d/framingham-net-software-developer/7018509536.html
#
# compensation: Salary
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# ** Please Apply Here : https://careers-healthdrive.icims.com/jobs/5186/c%23-.net-software-developer/job **
#
# Overview:
#
# We are seeking a seasoned software programmer with full life cycle application development experience. The Mid-Level Software Programmer must be experienced in participating in the development, implementation, testing and support of enterprise software applications in a healthcare services company.
#
# Sample Project Scope:
#
# 1.Developing and enhancing Electronic Health Records
# 2.Developing and enhancing Billing and Practice Management Systems
# 3.Web portal development
# 4.Interface with back-end Billing, scheduling and patient management systems
# 5.C# Command Line Routines
# 6.Third party software integrations
# 7.Existing product support
# 8.New product development
#
#
# Responsibilities:
#
# Specific required technical skills include, but are not limited to:
#
# 1.Required: Technical experience in Visual Studio 2019/2017 with emphasis on C#.NET (WinForms, ASP. NET MVC/ ASP .NET Core, UX design);
# 2.Required: MS SQL Server 2017/2012/2008 (experience writing complex stored procedures, triggers);
# 3.Preferred: Experience developing reports in Crystal Reports 2008 or higher
# 4.ASP .NET 4.5 / JavaScript
# 5..Net 4.5 and higher, Entity Framework
# 6.EDI, Medical/Dental billing expertise desirable
# 7.SQL Server management skills, ETL, data warehousing and business intelligence
# 8.API & Web services
# 9.DevExpress
# 10.Team Foundation Server
#
# Qualifications:
#
# Bachelor Science Degree in Computer Science, or equivalent field. At least 3-5 years of .NET (C#.NET, ASP.NET or VB.NET) experience with at least 5-10 years of software applications. Healthcare and/or Health Services software Experience is ideal. Proficiency in communicating with end users and third party development vendors is a must.
#
# This position requires an individual that can work independently while being a key contributor of a small development team. The Programmer must be very familiar and capable in contributing to the design process and have experience with complex, multi-tiered applications.
#
#
#
# The successful candidate will have the following personal skills and attributes (in addition to the technical requirements for the job already mentioned):
#
# -Resourceful self-starter who understands the sense of urgency and the importance of accountability to the end user.
# -Displays courtesy, tact and patience during interactions with all members of the company.
# -Mature, calm demeanor under stress.
# -Ability to work independently and take initiative.
# -Excellent organizational skills with the ability to handle multiple projects.
# -Innovative, forward thinker who is creative in planning and problem solving
# -Must be able to juggle many tasks simultaneously and still be able to handle any problems that arise unexpectedly.
# -High energy level with strong motivational skills.
# -Passion for customer service and business growth.
# -Confident and creative.
# -Acts in an ethical manner at all times and demands the same in others.
# -Strong experience in process troubleshooting and timely resolution of issues.
#
# ** Please Apply Here : https://careers-healthdrive.icims.com/jobs/5186/c%23-.net-software-developer/job **
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location: N/A
# Date: Nov 11
# Link: https://boston.craigslist.org/nwb/sof/d/boston-jr-software-developer-opt-cpt/7017837770.html
#
# compensation: 60k-70k
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Jr. Software Developer - OPT & CPT
# © craigslist - Map data © OpenStreetMap
# (google map)
#
# compensation: 60k-70k
# employment type: full-time
# Training and placement in 6 weeks!
# - 600 consultants placed at fortune 500 clients
# - Based out of Washington DC Metro
# - Requires basic programming skills in one or more (C/C++/Java/.NET)
# - Training and Placement in Java, .NET, iOS, Android, UI, QA, Mobile Testing
# - Training geared towards entry-level developers and recent grads
# - Relocation and accommodation
# - OPT/CPT welcome. H1B/GC sponsorship
#
# ****************************************
# Email your resumes today along with a basic overview of your technical/programming skills and your current work authorization (i.e. F1, H1B, GC, US Citizen).
# ****************************************
# ---
# Job Title: Senior Magento 2 Backend Developer
# Location: N/A
# Date: Nov  9
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-magento-2-backend/7016890026.html
#
# compensation: Negotiable
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# We’re looking for a highly skilled and motivated Senior Magento Backend Developer with at least 3 years of experience to become a core member of our team. We want you if you’re a self-motivated, detail oriented, team-player with strong communication skills. You will be responsible for finding solutions to complex problems related to Magento sites, and providing updates for Magento software and Magento based sites.
#
# Required Experience:
# Magento 1 and 2 Experience
# PHP
# SOAP
# Curl
# Command Line SVN/GIT
# Advanced MySQL
# OOP
# Zend
# Telecommuting
#
#
# Please send resume as an attachment.
#
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Nov  8
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7016362963.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Nov  8
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7016355028.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: SQL Server Developer/Analyst
# Location: Woburn, MA
# Date: Nov  8
# Link: https://boston.craigslist.org/bmw/sof/d/woburn-sql-server-developer-analyst/7016111801.html
#
# compensation: Commensurate with experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Northeast Retirement Services (NRS) offers administration and processing solutions for large Financial Services in the area of employee benefit plans and charitable programs, including services for all types of defined contribution, defined benefit plans, endowment programs and charitable trusts. Our clients include Institutional Investors, brokers, advisors and financial services firms requiring flexible, customized platforms for their customers. NRS business model enables us to create an integrated approach that provides responsive & comprehensive solutions.
#
# NRS leverages technology and its partners’ strengths to bring measurable value to our clients. Our teams address strategy, operations, risk and technical issues in formulating end-to-end administrative solutions that are tailored to a client's specific situation and processing requirements.
#
# NRS is looking for a SQL Server Developer/Analyst who can analyze client requirements and design, develop and maintain complex databases and act as Client IT Liaison.
#
# Job Functions
#
# -Design, Develop and support SQL Server Databases for complex business processes.
# -Work very closely with various Business groups to gather client requirements, analyze the data and act as Client IT Relationship person.
# -Develop and Maintain Queries, Stored Procedures and functions to implement business logic.
# -Develop complex reports using SQL Reporting Services and Active Reports.
# -Support senior management on data analysis and reporting projects.
# -Database performance tuning, troubleshooting, and various database administration tasks.
#
# Requirements
#
# -5 Years experience with SQL Server Database Development.
# -Significant knowledge of object oriented development principles, multi-tier web application design and relational database principles.
# -Bachelors Degree with 5+ years of experience.
# -Strong analytical, problem solving skills and excellent verbal and written communication skills.
# -Ability to make decisions, and render advice in a fast-paced environment with tight deadlines and competing priorities
# -Ability to work on multiple concurrent projects with flexibility to adapt to any given situation.
# -Ability to collaborate effectively with colleagues, senior management and 3rd party service providers to further the company's strategic objectives.
# -Experience in a financial services environment is a plus.
#
# Benefits
#
# NRS offers a generous benefits package including Paid Vacation, Sick time, medical/dental insurance, FSA and 401K Plan.
#
#
#
# ---
# Job Title: Senior Software Engineer
# Location: North Station, Boston
# Date: Nov  7
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer/7015660369.html
#
# compensation: $140,000 - $160,000 +RSU's
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
#
# Our client has built a world-class team of thinkers and problem solvers who prioritize individual growth and team collaboration over ego and attitude, while building products that solve the world's toughest security challenges.
#
# You'll deliver the future of an originator and innovator in the SOAR (Security Orchestration, Automation, and Remediation) product space. You'll participate in every aspect of product development from design and planning, through implementation and testing, to deployment and support.
#
# You'll be involved at the ground level in building and maintaining UI components for customers using an automation platform to make their jobs easier and more effective. You'll help design, plan, and implement these features alongside your peers in small teams, and be part of a larger team working together to support the platform.
#
# This team values attitude and willingness to learn over ego and experience, and wants someone who is looking to grow with the team as they continue to grow this product.
#
# The Stack:
#
#  Go
#
#  React 16
#
#  Postgres
#
#  Redis
#
#  Docker + Kubernetes
#
#  Terraform
#
#  AWS
#
# You need to be:
#
#  Focused on shipping solutions to problems, not just code.
#
#  Comfortable leading projects holistically - managing the technical details, organizing and planning epics, and helping others understand the priorities and needs of that work.
#
# ...
#
# We value diversity at our company and we are an equal opportunity employer. We do not discriminate on the basis of race, religion, color, national origin, gender, sexual orientation, age, marital status, veteran status, or disability status. Rather, we seek-out and celebrate people with diverse backgrounds, perspectives, and experiences.
#
# The position is full time, on-premises at either our office in Boston, MA. The job is not open to remote workers. No recruiters, please.
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Oct 24
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7006422188.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Oct 24
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7006415440.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: Entry Level Web Developer
# Location: N/A
# Date: Nov 19
# Link: https://providence.craigslist.org/sof/d/newport-entry-level-web-developer/7023396802.html
#
# compensation: $15.00/hr to start with 30-Day review
#
# employment type: part-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Local company looking for an Entry Level, full stack web developer to produce scalable software solutions.
#
# Local to RI/MA candidates only. On-prem position only.
#
# The right candidate will join a cross-functional team that’s responsible for the full software development life cycle, from conception to deployment.
#
# The right candidate should be comfortable around both front-end and back-end coding languages, development frameworks and third-party libraries and also be a team player with a capacity for visual design and utility.
#
# Responsibilities
# - Design client-side and server-side architecture
# - Build the front-end of applications through appealing visual design
# - Develop and manage well-functioning databases and applications
# - Write effective REST APIs
# - Test software to ensure responsiveness and efficiency
# - Troubleshoot, debug and upgrade software
# - Create security and data protection settings
# - Build features and applications with a mobile responsive design
# - Write technical documentation
#
# Requirements
#
# - Proven experience as a full stack web developer or similar role
# - Familiarity with common web technologies
# - Experience with multiple front-end languages and libraries (e.g. HTML/ CSS, JavaScript, XML, jQuery)
# - Experience with Wordpress and Magento CMS Platforms
# - Experience with multiple back-end languages (e.g. C#, Java, Laravel, Cake PHP) and JavaScript frameworks (e.g. Angular, React, Node.js)
# - Familiarity with databases (e.g. MySQL, MongoDB), web servers (e.g. Apache) and UI/UX design
# - Excellent communication and teamwork skills
# - Great attention to detail
# - Organizational skills
# - An analytical mind
#
# Reply to this posting with your resume. Applications must include a resume from a local-to-RI/MA candidate to be considered.
# On-prem position only.
# ---
# Job Title: Software and Data Engineer (full-stack)
# Location: N/A
# Date: Oct 24
# Link: https://providence.craigslist.org/sof/d/north-kingstown-software-and-data/7006516880.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Axiom Data Science, LLC
# http://axiomdatascience.com/about/
#
# Title: Software and Data Engineer (full-stack)
#
# Location: North Kingstown, RI
#
# This position may also work from one of our offices in Anchorage, AK; Fairbanks, AK; or Portland, OR, depending on the candidate.
#
# What we do
# Axiom is a small and dynamic (~20 person) technology and informatics firm with a mission to build a better understanding of society and the environment by increasing the accessibility, reuse, and impact of scientific data. To that end, we provide cyberinfrastructure support, data management systems, and scalable solutions for organizing and analyzing large amounts of diverse datasets to organizations across the globe. We’ve assembled an outstanding team of software developers, data analysts, and data coordinators to tackle difficult problems and provide excellent support to our partners at businesses, non-profits, federal and state agencies, and universities. Axiom is headquartered in Anchorage, Alaska and has satellite offices in Portland, Oregon; North Kingstown, Rhode Island; Homer, Alaska; and Fairbanks, Alaska.
#
# How we work
# We are not a consulting firm, we are a mission driven technology partner. We believe in focusing time and energy on our core products, forming mutually beneficial partnerships with clients, and encouraging developers to take ownership of their work.
#
# We are a geographically distributed company and collaborate with each other online. Strong communication skills are critical. We work together closely while minimizing distractions.
#
# We have low administrative overhead. Our employees are given all the tools they need to excel and are self-driven, resourceful, and instrumental in expanding our vision.
#
# We value uptime. Our systems are horizontally scalable and redundant. We care about discovering issues before our users are affected.
#
# What you’ll do
# The Axiom team works to enhance and sustain scientific data by upscaling metadata, semantically linking datasets, developing specialized services, creating powerful visualizations, and applying advanced analysis techniques. As a full-stack software and data engineer you will touch everything from front-end code to our high performance computing infrastructure. You will develop new features and applications as well as support existing applications written by the team. This will include front-end development of web applications, user interfaces, data visualizations, and documented web APIs as well as back-end development of web services, software tools, analysis pipelines/applications, and efficient data storage/access techniques.
#
# What you’ll work with
# Our stack is constantly evolving, with decisions on technologies made by engineers. You’ll work with a wide range of technologies and you are not expected to have experience with all of these technologies from the start; a demonstrated ability to learn new technologies and select appropriate technologies for each solution is more important.
#
#
# Frontend: Backbone, React, Vue, D3
#
# Backend: Java, Python, Node
#
# Storage: PostgreSQL, GlusterFS, Redis, ElasticSearch, MongoDB, TimescaleDB, Kafka
#
# Analysis: Apache Spark, Dask, Numpy, Pandas, scikit-learn, Tensorflow, Keras
#
# DevOps: GitLab (SCM, CI), Docker, Ansible, Prometheus, Fluentd, Grafana, Loki
#
# Specialized: NetCDF, Apache Arrow, GeoServer, OGC standards
#
#
# What we look for
# As above, you are not expected to meet all of the criteria below. A demonstrated history working with and delivering real-world software is key.
#
#
# BS or MS in Computer Science or equivalent experience
#
# Strong experience in full-stack web application development, including database design, architecture, services, and APIs
#
# Experience with modern front-end development and web frameworks
#
# Experience with the data science / scientific Python stack
#
# Experience working as a member of a software engineering team
#
# Experience working with data from the physical or biological sciences
#
# Self-motivation, independence, flexibility, and a problem-solving attitude
#
#
# What you’ll get
# A healthy work/life balance and a competitive salary commensurate with experience. Benefits include 5 weeks paid leave plus holidays, healthcare reimbursement, a company 401K plan, and a gym membership.
#
# How to apply
# Reply to this post with your resume and cover letter by November 15, 2019. Include 'Software and Data Engineer' in the subject line. The following additional application materials are recommended, but not required: code samples, profile links to GitHub/StackOverflow; descriptions and screenshots of a completed project; and other examples of expertise or open source participation.
#
# ---
# Job Title: Python Software Engineer
# Location: N/A
# Date: Nov  8
# Link: https://hartford.craigslist.org/sof/d/hartford-python-software-engineer/7016071955.html
#
# compensation: $45-50K
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Join a small team of engineers at a leading national mobility company that is responsible for maintaining a variety of high-tech products. You will be creating and maintaining back-end applications that are highly visible.
#
# You’ll love this job if you are curious and interested in exploring all aspects of the development lifecycle: planning, development, deployment, and maintenance. You will work directly under the Senior Software Engineer to deliver results in a fast-paced environment.
#
# In addition to a competitive salary, you’ll have the opportunity to be a part of a team that will positively impact the lives of many people daily.  There will be opportunity to grow in the company.
#
# Job Responsibilities:
# •	Maintain and develop various applications for data collection
# •	Consume APIs inside of your own applications effectively
# •	Query and maintain various forms of database—both SQL and No-SQL
# •	Learn new tools and implement them into existing infrastructure efficiently
#
# Job Requirements:
# •	Python
# •	SQL
# •	Linux
# •	General Cloud Platform knowledge (Google Cloud Platform, Amazon Web Services, Azure)
# •	Version control (Git preferred, but any is acceptable)
# •	Self-motivated with the ability to primarily work independently outside of meetings
# •	Communicate effective deliverable dates and execute on them
# •	Ability to analyze problems and solve them quickly and effectively
# •	Excellent interpersonal skills
#
# Nice to Haves:
# •	Docker experience
# •	Working understanding of networking
#
# Recent Computer Science graduate preferred, or equivalent training with demonstrable deployments.  There will be a take home micro-assignment for all interviewees.
#
# If you have a passion to develop software and your experience aligns with this job, come interview with us!
# ---
# Job Title: Node.js Software Engineer
# Location: N/A
# Date: Nov  8
# Link: https://hartford.craigslist.org/sof/d/hartford-nodejs-software-engineer/7016059857.html
#
# compensation: $45-50K DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Join a small team of engineers at a leading national mobility company that is responsible for maintaining a variety of high-tech products. You will be creating and maintaining back-end applications that are highly visible.
#
# You’ll love this job if you are curious and interested in exploring all aspects of the development lifecycle: planning, development, deployment, and maintenance. You will work directly under the Senior Software Engineer to deliver results in a fast-paced environment.
#
# In addition to a competitive salary, you’ll have the opportunity to be a part of a team that will positively impact the lives of many people daily.  There will be opportunity to grow in the company.
#
# Job Responsibilities:
# •	Maintain and develop various applications for data collection
# •	Consume APIs inside of your own applications effectively
# •	Query and maintain various forms of database—both SQL and No-SQL
# •	Learn new tools and implement them into existing infrastructure efficiently
#
# Job Requirements:
# •	JavaScript / Node.js
# •	SQL
# •	Linux
# •	General Cloud Platform knowledge (Google Cloud Platform, Amazon Web Services, Azure)
# •	Version control (Git preferred, but any is acceptable)
# •	Basic front-end proficiency (HTML, CSS)
# •	Self-motivated with the ability to primarily work independently outside of meetings
# •	Communicate effective deliverable dates and execute on them
# •	Ability to analyze problems and solve them quickly and effectively
# •	Excellent interpersonal skills
#
# Nice to Haves:
# •	Docker experience
# •	Working understanding of networking
#
# Recent Computer Science graduate preferred, or equivalent training with demonstrable deployments.  There will be a take home micro-assignment for all interviewees.
#
# If you have a passion to develop software and your experience aligns with this job, come interview with us!
#
# ---

# %% [markdown]
# #Show job no

# %%
job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('p',{'class':'result-info'})
    
    for job in jobs:
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        job_no+=1
        print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
# Out:
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7024696124.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Job Referrals Available for Amazing Tech/Software Positions
# Location: N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-job-referrals-available-for/7024692015.html
#
# compensation: Determined by the job
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# The adage of "It's who you know, not what you know" really is difficult to reconcile when you feel like you have no network to get to your next career step.
#
# Over the past 12 years, I heard this advice a lot as I moved around from city to city—both in the US and abroad. With every move, I had to rebuild my network, and it was *really* difficult each time.
#
# If you're someone who's ever experienced a life transition, like a career change, having a child, or deciding to return to work after taking an extended leave, then this story is probably all too familiar.
#
# If you're a woman, minority, or person with a non-traditional background which, when combined, represents the majority of the U.S. population, then it's *really* difficult to make any change because people already have these preconceived notions about you.
#
# It's not an excuse, but an acknowledgment that biases are our reality.
#
# Our reality is harsh on the job search. And we all could use help in fending off common biases in our job search so we can overcome the challenges we face in our transitions.
#
# That's why we built JobFit - to help people in transition broaden the "who you know," so you can show them your "what you know." We primarily assist people who are interested in transitioning to a new city for their next career step.
#
# Whether you want to move for family, a change of scenery, or better opportunities, our goal is to help people find job referrals in cities where they want to work.
#
# Find any job referral for any specific job to any particular company.
#
# Our process of applying for job referrals is simple.
#
# 1. Find a company where you want a job referral.
# 2. Anonymously answer a few questions on what interested you about the company. Anonymity is to protect you from bias against your location, among other hiring bias.
# 3. A non-recruiter employee at the company will review your answers. If the employee likes your responses, they gain access to your name and resume for the job referral.
#
#
# Here are some job referrals you can directly start connecting to right away:
#
# For a job referral to DroneDeploy - https://formyreferral.getjobfit.com/MXBH7tBNl1?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=dronedeploy%2C%20v1&utm_content=sponsor_link
#
# For a job referral to Intel - https://formyreferral.getjobfit.com/Db5XfR1HKZ?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=intel%2C%20v1&utm_content=sponsor_link
#
# For a job referral to Accenture - https://formyreferral.getjobfit.com/0cPmVsfLb1?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=accenture%2C%20v1&utm_content=sponsor_link
#
# For a job referral to Google - https://formyreferral.getjobfit.com/7pFy7DahVW?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=google%2C%20v1&utm_content=sponsor_link
#
#
# We have resources to get you more job referrals to anywhere you want. You can explore other jobs in the remaining 70,000 companies in our network. Don't let your location limit your goals. You can even find job referrals for remote jobs if you wish.
#
#
# Check out JobFit for more details.
#
# https://getjobfit.com/?utm_source=craigslist&utm_medium=software_qa_dba_etc&utm_campaign=boston&utm_term=v1
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Nov 21
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7024690835.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: Manual Mobile QA Tester (Native Apps - local candidates only)
# Location: Boston
# Date: Nov 18
# Link: https://boston.craigslist.org/gbs/sof/d/boston-manual-mobile-qa-tester-native/7022545596.html
#
# compensation: Competitive
#
# employment type: contract
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# LOCAL CANDIDATES ONLY – MUST HAVE MOBILE TESTING EXPERIENCE
#
# Our client, a leading digital marketing agency in Boston, is looking to hire a QA Engineer with mobile application testing experience ASAP.  This is a 6 month contract assignment to start with potential for extensions, or even a temp to hire for the right person.
#
# Take proactive, expert ownership of Quality Assurance role on client and internal projects
# Author test plans, test cases, and/or test scripts required to validate solutions
# Partner closely with the development teams to replicate and resolve issues
# Work closely across all capabilities (e.g. Technology, Project Management, User Experience/Creative, etc.) to ensure that all quality assurance requirements are defined and properly documented
# Assist in reviewing and refining existing QA process, controls, and best practices
# Act as a strong advocate for quality and share QA knowledge to other team members within the company
# Ensure all projects meet both functional and non-functional requirements and map to QA test cases
# Assist QA Leadership in training and mentoring other QA staff members on QA best practices and techniques
#
# Qualities and Experience for the Mobile QA Tester:
#
# Expertise in various forms of software testing: functional and non-functional testing – regression testing, performance testing, etc.
# Experience testing native mobile applications for iOS and Android is a FIRM REQUIREMENT.
# Experience in cross device/cross OS version testing of native mobile applications
# Experience testing native mobile applications under degraded/slow/no network conditions
# Responsive Design testing experience
# Ability to understand business needs and translate them into test cases and test scenarios
# Demonstrated ability to work collaboratively with teams and clients
# Extensive understanding in QA process (Agile and Waterfall), tools, and approaches
# Experience with JIRA, Agilecraft, or similar bug and issue tracking solutions
# Experience with Mobile Web testing and simulator/emulation tools
# Knowledge of Selenium test automation a strong plus
# Experience with Blazemeter / JMeter/load testing tools, and performance testing tools a plus
# Experience with testing beyond functional (e.g. Web Accessibility, security, etc.) a plus
#
# Education for the Mobile QA Engineer:
#
# 3-5 or more years of Software Quality Assurance experience
# BS/MS in Computer Science or equivalent preferred
# ---
# Job Title: Software Development Engineer I
# Location: Waltham, MA
# Date: Nov 18
# Link: https://boston.craigslist.org/bmw/sof/d/waltham-software-development-engineer/7022471531.html
#
# compensation: DOE + benefits
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Yardi Systems is currently seeking a full time, highly motivated Software Development Engineer I to join their growing team in Waltham, MA!
#
# In response to continued demand for our services, Yardi Resident Screening is looking for a Software Development Engineer to join our team in Waltham, MA.  Reporting to the Director of Information Technology, you will be a core member of our software development team.   You will leverage your analytical problem solving skills to support and enhance our Linux and web based systems utilizing your solid Java programming skills, database skills and knowledge of open source tools.
# Responsibilities
#
# Perform development tasks including programming, unit testing, and database design.
# Contribute to integration and general system regression testing.
# Participate on installs and provide on-going production support.
#
# Requirements
#
# BS or MS Degree in Computer Science, Systems Engineering or related field.
# 2+ years’ experience in Software Development.
# Interest to contribute to systems architectural improvements.
# Excellent verbal and written communication skills as well as being a team player.
# 1+ years of experience working on multi-tiered web application architecture.
# 1+ years supporting and developing production systems using Linux, Java, XML , JAXB, JSP, JavaScript, JQuery, Tomcat, web services.
# Good relational databases skill using PostgreSQL or Oracle with JDBC, SQL, Hibernate.
# Experience with Eclipse IDE and use of source repositories.
# Experience with 3rd Party API Integration (web services,…)
# Solid object oriented skills and conceptual understanding.
# Understanding of the product development lifecycle through design, development, testing, rollout, and support.
# Ability to understand and document business requirements.
# Ability to work with multi-site and off-shore development teams.
# Availability for occasional night, weekend, and holiday work assignments.
#
#
# PLEASE APPLY TO: https://careers.yardi.com/openings/job-posting/RS19413744/
#
# Yardi Systems is a successful independent software company with a proven history of growth and market leadership in the multi-billion dollar global commercial real estate industry. We employ talented, motivated and innovative people that are focused on delivering superior solutions to our clients and are passionate about working with other highly skilled professionals in team environments.
#
# If you are seeking an opportunity to join a winning team, work with the latest Microsoft technologies and develop your career, then Yardi Systems is the place for you. We have a pleasant and casual work environment, competitive salaries, and a comprehensive benefits package. Our corporate culture stresses integrity, respect, trust, responsibility, and fun.
#
# EOE Race/Gender/Disability/Vets
#
#
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location: N/A
# Date: Nov 18
# Link: https://boston.craigslist.org/sob/sof/d/boston-jr-software-developer-opt-cpt/7022322359.html
#
# compensation: 60k-70k
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Jr. Software Developer - OPT & CPT
# © craigslist - Map data © OpenStreetMap
# (google map)
#
# compensation: 60k-70k
# employment type: full-time
# Training and placement in 6 weeks!
# - 600 consultants placed at fortune 500 clients
# - Based out of Washington DC Metro
# - Requires basic programming skills in one or more (C/C++/Java/.NET)
# - Training and Placement in Java, .NET, iOS, Android, UI, QA, Mobile Testing
# - Training geared towards entry-level developers and recent grads
# - Relocation and accommodation
# - OPT/CPT welcome. H1B/GC sponsorship
#
# ****************************************
# Email your resumes today along with a basic overview of your technical/programming skills and your current work authorization (i.e. F1, H1B, GC, US Citizen).
# ****************************************
# ---
# Job Title: Senior Software Developer (Remote Available)
# Location: Virginia Beach
# Date: Nov 15
# Link: https://boston.craigslist.org/gbs/sof/d/virginia-beach-senior-software/7020506451.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Our Development Team is looking for a Senior Software Developer to join them in shaping our company by creating, enhancing, and maintaining PHP based internal and external products. As part of the team, you will work within the LAMP stack in an Agile based environment to help ensure our products provide a great user experience and significant value to the customer.
#
# This role can be filled remotely or from one of our offices.
#
# What You’ll Do:
#
# Develop structured application/interface code, new program documentation, operations documentation and user guides in a casual, flexible environment
# Communicate with end users and internal customers to develop, debug, and test application software for accuracy, integrity, interoperability and completeness.
# Produce reliable, testable software applications using a disciplined development approach
# Utilize your advanced PHP and MySQL skills to create back end tooling
# Collaborate with stakeholders and leadership to prioritize and implement features
# Develop new functionality and applications on cross functional Agile project teams
# Review and test team member’s code to ensure the software meets our high quality standards and operates efficiently
# Build your skill set in a collaborative, team-focused environment
#
# Ideal Candidates Have:
#
# 5-8 years progressive development experience, primarily focused on web applications, back end automation
# Bachelor’s Degree in Computer Science and/or equivalent experience
# Extensive background in LAMP development
# Ability to move back and forth between Front End and API Back End work
# Experience with UI/UX fundamentals
# Advanced experience with  PHP and MySQL
# Advanced understanding of object oriented principles
# Talent for building user interfaces using JS, jQuery, HTML, CSS and AJAX
# Background in refactoring/verifying systems through automated testing and test-driven development in large scale systems
# Experience with software deployment, Continuous Integration (CI), and Continuous Delivery (CD) concepts, applications, and tools highly preferred
# Basic knowledge of the Linux/Unix command-line
# Experience with MVC frameworks required, Zend Framework preferred
# Advanced JavaScript experience and mid-level or better experience with one or more of the common frameworks like React or Angular is a plus
# Experience in the WordPress ecosystem building or modifying plugins preferred
# A passion for creating a high quality user experience
# Experience with development of automated customer processes and systems
#
# What You’ll Get:
#
# Profit sharing twice a year
# Medical, dental, vision, disability, life insurance, and 401K plans
# Casual work environment and relaxed dress code
# Free weekly lunch and snacks
# Tuition and certification reimbursement
# Opportunities for advancement after 90 days
# To be a part of an incredible team in a collaborative environment
#
# Location:
#
# Denver, CO
# Virginia Beach, VA
# Remote
#
# See what it's like working at InMotion and all the great perks that come with it. You can also check out our products here.
#
# Apply Here...
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7020245669.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7020241473.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: Platform Engineer
# Location: boston: boston/cambridge/brookline
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-platform-engineer/7020204286.html
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Platform Engineer/Backend (Boston, MA)                         compensation: $150KA Boston based Cloud Security Platform provider that is building the next frontier of software security,  seeks to hire a full-time Platform Engineer to join its team in downtown Boston!YOUR CAREER GOALSYou want to build highly scalable and dependent software solutions within the ever growing cloud security space. You enjoy working up and down the platform stack, from datastores to REST APIs. You enjoy exploring new ways to efficiently ingest, process, store, and leverage the vast amount of data this firm captures. You want to have a vocal role on a team looking to constantly improve their product.YOUR AMAZING QUALITIESYou're passionate about building and scaling high-volume, highly available SaaS solutions. You enjoy API design for internal and external customers. . You recognize process or programming inefficiencies and can recommend improvements in a heartbeat. You have a B.S. degree or higher in Computer Science, Information Technology & Services, Software Engineering, or a related field, and at least two years of professional experience in the full lifecycle development of software applications using:Node.jsScalaPythonElasticSearchRabbitMQCassandraAWSYou must also be able to thrive in a fast-paced, deadline-driven environment. Leadership ability and excellent interpersonal & communication skills here are absolutely essential.IN EXCHANGE FOR YOUR HARD WORKWe offer you:Scale Challenges that allow you to directly influence and build software that is processing billions of events per dayA cohesive engineering team where software and infrastructure engineers work side-by-side during release cycles, resolving bottlenecks, and improving reliability and scalabilityComprehensive healthcare coverage, including HMO/PPO plans, dental, vision, life, short-term and long-term disabilityGenerous PTO (3 weeks!)401(k) planEquity GrantsCommuter/Transit expense subsidyCompany supplied treats and snacksAnd much more!Find Us on Facebook!Follow Us on Twitter!Beacon Hill is an Equal Opportunity Employer that values the strength diversity brings to the workplace. Individuals with Disabilities and Protected Veterans are encouraged to apply.Company Profile:Beacon Hill Technologies, a premier National Information Technology Staffing Group, provides world class technology talent across all industries on a contract, direct (permanent), contract-to-direct and project basis.  Beacon Hill Technologies' dedicated team of recruiting and staffing experts consistently delivers quality IT professionals to solve our customers' technical and business needs. Beacon Hill Technologies covers a broad spectrum of IT positions, including Project Management and Business Analysis, Programming/Development, Database, Infrastructure, Quality Assurance, Production/Support and ERP roles.Learn more about Beacon Hill Staffing Group and our specialty divisions, Beacon Hill Associates, Beacon Hill Financial, Beacon Hill HR, Beacon Hill Legal, Beacon Hill Pharma and Beacon Hill Technologies by visiting www.beaconhillstaffing.com. We look forward to working with you.Beacon Hill. Employing the Future?
#
# ---
# Job Title: Senior Magento Frontend Developer
# Location: N/A
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-magento-frontend-developer/7019962471.html
#
# compensation: Negotiable
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
# We’re looking for a highly skilled and motivated Senior Magento Frontend Developer with at least 3 years of experience. We want you if you’re a self-motivated, detail oriented, team-player with strong communication skills. You will be responsible for finding solutions to complex problems related to Magento sites, and providing updates for Magento software and Magento based sites.
#
# Required Skills:
# 3+ years experience as a Magento front-end developer
# CSS / HTML / JS and JQuery
# LESS, SASS & COMPASS
# Experience converting PSDs into HTML & CSS
# Expertise with slicing designs into the Magento templating system
# Pride in your ability to use Magento best practices with your front-end code
# Demonstratable History of magento UI
# Graphic design experience is an asset
# Excellent written and verbal communication
#
# Please Include Resume as an Attachment
#
#
# ---
# Job Title: Full stack / Django Python developer
# Location: Boston
# Date: Nov 14
# Link: https://boston.craigslist.org/gbs/sof/d/boston-full-stack-django-python/7019788209.html
#
# compensation: Hourly rate / TBD
#
# employment type: employee's choice
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
#
#
#
# Hello,
#
# Alyx Health is a startup developing a solution for nurse practices. Alyx Health is looking for 2 developers with a deep knowledge of Django.
#
# The company currently works in Downtown Boston.
# We're looking for a good mix of professional skills with a capability to work within a team and have the desire to learn the needs of the industry.
#
# Our preferences are for developers who can be in our office in Boston.
#
# Location: Boston area
#
# Main qualifications:
# - Python (3)
# - Django
# - AWS
# - MySQL
# - Javascript / JQuery
# - CSS
# - Git/Github
# - REST API
#
# In addition, knowledge with JS frameworks and mobile development will be a plus.
#
# Please email your resume and indicate any experience relevant to the position.
#
# Start - Nov. 2019.
#
# -------------------------------------------------------------------------
# Python, Django, REST API, CSS, Javascript, JQuery, AWS, Database, MySQL, JSON, Healthcare
# ---
# Job Title: Facilities Assistant
# Location: Medford
# Date: Nov 13
# Link: https://boston.craigslist.org/gbs/sof/d/medford-facilities-assistant/7019155881.html
#
# compensation: Commensurate with Experience.
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Founded locally in 1969 by Marshall M. Sloane, Century Bank is New England's largest family‐run bank with 27 branches throughout Greater Boston. Today Century Bank is the Bank families and businesses rely on -- a place where you can count on getting personal attention. Whether you need a free checking account, easy online banking or a sophisticated financial solution, you'll find it at Century Bank. For more information, visit www.CenturyBank.com.
# Currently, we are searching for enthusiastic individuals to join the Century team!
# Job Overview:
# ---
# Job Title: DevOps Engineer
# Location: N/A
# Date: Nov 12
# Link: https://boston.craigslist.org/gbs/sof/d/boston-devops-engineer/7018950123.html
#
# compensation: Based on Experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Job Title: DevOps Engineer
# Location: Boston, Massachusetts
#
# A digital health company providing Care Pathway Management solutions is looking for a DevOps Engineer to maintain and develop its world-class, web-based, healthcare platform.
#
# Key Responsibilities:
#
# ● Working within the Technical Operations team on a day-to-day basis, supporting requests and requirements for new and existing infrastructure/software
# ● Assist in developing the companies infrastructure using automated tools, writing or employing
# routines to support/manage the platform
# ● Working with the broader business in order to solve customer issues such as integrations
# requirements
#
# Essential Experience:
#
# A 4-year degree in Computer Science or similar experience
# Strong background in Linux/Unix Administration
# Excellent LEMP (Linux, Nginx, MySQL, PHP) administration experience
# Expert understanding of cloud-based Web architecture
# Good knowledge of AWS
# Experience of systems automation technologies (e.g. Ansible, Terraform)
# Fluent in SQL, including data migration tasks
# Strong experience with bash shell and other scripting languages
# Familiarity with database administration and tools, such as stored procedures and optimization
#
# Bonuses:
#
# Experience in a PCI-DSS or ISO 27001-compliant environment
# Understanding of other languages such as Python, Ruby
# Experience with systems integration, healthcare specifically (e.g. HL7, MirthConnect, DICOM)
# Icinga, New Relic, Git, Jenkins, and varied open source technologies.
# PHP (Symfony) development skills
#
# ---
# Job Title: Full Stack Software Engineer
# Location: Cambridge, MA
# Date: Nov 12
# Link: https://boston.craigslist.org/gbs/sof/d/cambridge-full-stack-software-engineer/7018868025.html
#
# compensation: Commensurate with experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Apply here: https://superpedestrian.applytojob.com/apply/u89CFqFga2/Full-Stack-Software-Engineer?source=Craigslist
#
# Superpedestrian brings together a team of extraordinary people for one vision: transforming urban mobility. To work with us, you should possess a strong desire to change the way people everywhere move about cities. We're revolutionizing personal transit for a sustainable future. Superpedestrian is an equal opportunity employer, with women and minorities strongly encouraged to apply. We care about your skills and your character. If we think there's a good fit, we will get in touch. So please, no phone calls or recruiters.
#
# The software team at Superpedestrian works on our scooter and electric bike fleet management and Vehicle Intelligence system. This includes backend and APIs to support the rich data we collect, communication and security for IoT, manufacturing integration, research and support tools, mobile SDKs and much more!  We’re a tight knit, industrious bunch and we are seeking a Senior Software Engineer to join the team. The ideal candidate has strong skills in backend development, optimizing algorithms and database structures, but can contribute on multiple levels.
#
# There are currently several opportunities open in the software team, and we are looking for candidates at different stages of their career. Don't hesitate to apply if you only meet some of the preferred qualifications or if you feel you're overqualified. This is a position where you will have the opportunity to shape your responsibilities based on your skills and interests.
#
#
# What you'll do:
#  - Create multiple database-backed API backends
#  - Collaborate with cross-functional teams to define, design and ship new features
#  - Contribute across the stack on developing web applications, data layers, and back end services
#  - Unit-test code for robustness, including edge cases, usability and general reliability
#  - Work on improving application performance and bug fixes
#  - Continuously discover, evaluate, and implement new technologies to maximize development efficiency and application performance
#  - Participate in cross-team peer code reviews
#  - Participate in Agile Scrum sprint and release planning
#
# What we're looking for:
#  - 3+ years of industry experience building scalable backend services
#  - Significant experience with Python
#  - Experience with Django, Rails, Node or similar web framework
#  - Undergraduate degree in computer science or related field
#  - Experience with RESTful web services, JSON
#  - Working knowledge of database systems
# ---
# Job Title: C# .NET Software Developer
# Location: Framingham
# Date: Nov 12
# Link: https://boston.craigslist.org/bmw/sof/d/framingham-net-software-developer/7018509536.html
#
# compensation: Salary
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# ** Please Apply Here : https://careers-healthdrive.icims.com/jobs/5186/c%23-.net-software-developer/job **
#
# Overview:
#
# We are seeking a seasoned software programmer with full life cycle application development experience. The Mid-Level Software Programmer must be experienced in participating in the development, implementation, testing and support of enterprise software applications in a healthcare services company.
#
# Sample Project Scope:
#
# 1.Developing and enhancing Electronic Health Records
# 2.Developing and enhancing Billing and Practice Management Systems
# 3.Web portal development
# 4.Interface with back-end Billing, scheduling and patient management systems
# 5.C# Command Line Routines
# 6.Third party software integrations
# 7.Existing product support
# 8.New product development
#
#
# Responsibilities:
#
# Specific required technical skills include, but are not limited to:
#
# 1.Required: Technical experience in Visual Studio 2019/2017 with emphasis on C#.NET (WinForms, ASP. NET MVC/ ASP .NET Core, UX design);
# 2.Required: MS SQL Server 2017/2012/2008 (experience writing complex stored procedures, triggers);
# 3.Preferred: Experience developing reports in Crystal Reports 2008 or higher
# 4.ASP .NET 4.5 / JavaScript
# 5..Net 4.5 and higher, Entity Framework
# 6.EDI, Medical/Dental billing expertise desirable
# 7.SQL Server management skills, ETL, data warehousing and business intelligence
# 8.API & Web services
# 9.DevExpress
# 10.Team Foundation Server
#
# Qualifications:
#
# Bachelor Science Degree in Computer Science, or equivalent field. At least 3-5 years of .NET (C#.NET, ASP.NET or VB.NET) experience with at least 5-10 years of software applications. Healthcare and/or Health Services software Experience is ideal. Proficiency in communicating with end users and third party development vendors is a must.
#
# This position requires an individual that can work independently while being a key contributor of a small development team. The Programmer must be very familiar and capable in contributing to the design process and have experience with complex, multi-tiered applications.
#
#
#
# The successful candidate will have the following personal skills and attributes (in addition to the technical requirements for the job already mentioned):
#
# -Resourceful self-starter who understands the sense of urgency and the importance of accountability to the end user.
# -Displays courtesy, tact and patience during interactions with all members of the company.
# -Mature, calm demeanor under stress.
# -Ability to work independently and take initiative.
# -Excellent organizational skills with the ability to handle multiple projects.
# -Innovative, forward thinker who is creative in planning and problem solving
# -Must be able to juggle many tasks simultaneously and still be able to handle any problems that arise unexpectedly.
# -High energy level with strong motivational skills.
# -Passion for customer service and business growth.
# -Confident and creative.
# -Acts in an ethical manner at all times and demands the same in others.
# -Strong experience in process troubleshooting and timely resolution of issues.
#
# ** Please Apply Here : https://careers-healthdrive.icims.com/jobs/5186/c%23-.net-software-developer/job **
# ---
# Job Title: Jr. Software Developer - OPT & CPT
# Location: N/A
# Date: Nov 11
# Link: https://boston.craigslist.org/nwb/sof/d/boston-jr-software-developer-opt-cpt/7017837770.html
#
# compensation: 60k-70k
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Jr. Software Developer - OPT & CPT
# © craigslist - Map data © OpenStreetMap
# (google map)
#
# compensation: 60k-70k
# employment type: full-time
# Training and placement in 6 weeks!
# - 600 consultants placed at fortune 500 clients
# - Based out of Washington DC Metro
# - Requires basic programming skills in one or more (C/C++/Java/.NET)
# - Training and Placement in Java, .NET, iOS, Android, UI, QA, Mobile Testing
# - Training geared towards entry-level developers and recent grads
# - Relocation and accommodation
# - OPT/CPT welcome. H1B/GC sponsorship
#
# ****************************************
# Email your resumes today along with a basic overview of your technical/programming skills and your current work authorization (i.e. F1, H1B, GC, US Citizen).
# ****************************************
# ---
# Job Title: Senior Magento 2 Backend Developer
# Location: N/A
# Date: Nov  9
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-magento-2-backend/7016890026.html
#
# compensation: Negotiable
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# We’re looking for a highly skilled and motivated Senior Magento Backend Developer with at least 3 years of experience to become a core member of our team. We want you if you’re a self-motivated, detail oriented, team-player with strong communication skills. You will be responsible for finding solutions to complex problems related to Magento sites, and providing updates for Magento software and Magento based sites.
#
# Required Experience:
# Magento 1 and 2 Experience
# PHP
# SOAP
# Curl
# Command Line SVN/GIT
# Advanced MySQL
# OOP
# Zend
# Telecommuting
#
#
# Please send resume as an attachment.
#
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Nov  8
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7016362963.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Nov  8
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7016355028.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: SQL Server Developer/Analyst
# Location: Woburn, MA
# Date: Nov  8
# Link: https://boston.craigslist.org/bmw/sof/d/woburn-sql-server-developer-analyst/7016111801.html
#
# compensation: Commensurate with experience
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Northeast Retirement Services (NRS) offers administration and processing solutions for large Financial Services in the area of employee benefit plans and charitable programs, including services for all types of defined contribution, defined benefit plans, endowment programs and charitable trusts. Our clients include Institutional Investors, brokers, advisors and financial services firms requiring flexible, customized platforms for their customers. NRS business model enables us to create an integrated approach that provides responsive & comprehensive solutions.
#
# NRS leverages technology and its partners’ strengths to bring measurable value to our clients. Our teams address strategy, operations, risk and technical issues in formulating end-to-end administrative solutions that are tailored to a client's specific situation and processing requirements.
#
# NRS is looking for a SQL Server Developer/Analyst who can analyze client requirements and design, develop and maintain complex databases and act as Client IT Liaison.
#
# Job Functions
#
# -Design, Develop and support SQL Server Databases for complex business processes.
# -Work very closely with various Business groups to gather client requirements, analyze the data and act as Client IT Relationship person.
# -Develop and Maintain Queries, Stored Procedures and functions to implement business logic.
# -Develop complex reports using SQL Reporting Services and Active Reports.
# -Support senior management on data analysis and reporting projects.
# -Database performance tuning, troubleshooting, and various database administration tasks.
#
# Requirements
#
# -5 Years experience with SQL Server Database Development.
# -Significant knowledge of object oriented development principles, multi-tier web application design and relational database principles.
# -Bachelors Degree with 5+ years of experience.
# -Strong analytical, problem solving skills and excellent verbal and written communication skills.
# -Ability to make decisions, and render advice in a fast-paced environment with tight deadlines and competing priorities
# -Ability to work on multiple concurrent projects with flexibility to adapt to any given situation.
# -Ability to collaborate effectively with colleagues, senior management and 3rd party service providers to further the company's strategic objectives.
# -Experience in a financial services environment is a plus.
#
# Benefits
#
# NRS offers a generous benefits package including Paid Vacation, Sick time, medical/dental insurance, FSA and 401K Plan.
#
#
#
# ---
# Job Title: Senior Software Engineer
# Location: North Station, Boston
# Date: Nov  7
# Link: https://boston.craigslist.org/gbs/sof/d/boston-senior-software-engineer/7015660369.html
#
# compensation: $140,000 - $160,000 +RSU's
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
#
#
# Our client has built a world-class team of thinkers and problem solvers who prioritize individual growth and team collaboration over ego and attitude, while building products that solve the world's toughest security challenges.
#
# You'll deliver the future of an originator and innovator in the SOAR (Security Orchestration, Automation, and Remediation) product space. You'll participate in every aspect of product development from design and planning, through implementation and testing, to deployment and support.
#
# You'll be involved at the ground level in building and maintaining UI components for customers using an automation platform to make their jobs easier and more effective. You'll help design, plan, and implement these features alongside your peers in small teams, and be part of a larger team working together to support the platform.
#
# This team values attitude and willingness to learn over ego and experience, and wants someone who is looking to grow with the team as they continue to grow this product.
#
# The Stack:
#
#  Go
#
#  React 16
#
#  Postgres
#
#  Redis
#
#  Docker + Kubernetes
#
#  Terraform
#
#  AWS
#
# You need to be:
#
#  Focused on shipping solutions to problems, not just code.
#
#  Comfortable leading projects holistically - managing the technical details, organizing and planning epics, and helping others understand the priorities and needs of that work.
#
# ...
#
# We value diversity at our company and we are an equal opportunity employer. We do not discriminate on the basis of race, religion, color, national origin, gender, sexual orientation, age, marital status, veteran status, or disability status. Rather, we seek-out and celebrate people with diverse backgrounds, perspectives, and experiences.
#
# The position is full time, on-premises at either our office in Boston, MA. The job is not open to remote workers. No recruiters, please.
#
# ---
# Job Title: Data Science Fellowship
# Location: N/A
# Date: Oct 24
# Link: https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7006422188.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
#
# Pathrise (YC W18) invests in undervalued university students or young professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from heads of marketing of publicly traded companies to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 500 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
#
# The Pathrise Fellowship is a program for students and new grads that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry data scientists, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
#
# We seek to uplift and provide guidance for undervalued students and young professionals in their early career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
#
# You want to work with an experienced advisor who can give you expert advice.
# You are eager to start your career with a job or internship at a top tech company or a rapidly growing startup.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosdata&utm_medium=job_board
# ---
# Job Title: Software Engineering Fellowship
# Location: N/A
# Date: Oct 24
# Link: https://boston.craigslist.org/gbs/sof/d/boston-software-engineering-fellowship/7006415440.html
#
# compensation: 80,000-160,000
#
# employment type: full-time
#
# telecommuting okay
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# What is Pathrise
# Pathrise (YC W18) invests in undervalued tech professionals by coaching them to get a competitive job. The program is completely free upfront. In exchange, Pathrise fellows agree to pay back a share of their first year's salary if and only if they get hired.
#
# Pathrise is based on insights from hundreds of hiring managers in tech; this means everyone from Google recruiters to startup CEOs. We've been featured in TechCrunch, VentureBeat, EdSurge, and The Atlantic as the "Y Combinator for your career." To date, we've worked with over 600 fellows and have helped them land offers at Facebook, Uber, Google, Oath, Amazon, and other top companies or exciting startups.
#
# About the Fellowship
# The Pathrise Fellowship is a program for students and new professionals that helps you land the best job possible in tech.
#
# During the fellowship, you receive 1-on-1 mentorship from experienced industry engineers, analysts, managers, and recruiters. You learn systems to attract the attention of any company you want, find out insider information on how to ace your interviews, and more. We even directly refer you to companies in our network until you find a job you love.
#
# Our Mission
# We seek to uplift and provide guidance for tech professionals in their career. You can read more about our mission and how it all works on our website: www.pathrise.com.
#
# Qualifications
# You are interested in getting the best possible job in tech.
# You want to work with an experienced advisor who can give you expert advice whether you need to learn about data structures or UI/UX patterns.
# You want a team of advisors who will be by your side throughout the entire process, whenever you need, as long as you need.
#
# Please apply here: https://www.pathrise.com/?utm_source=craigslist&utm_campaign=bosswe&utm_medium=job_board
# ---
# Job Title: Entry Level Web Developer
# Location: N/A
# Date: Nov 19
# Link: https://providence.craigslist.org/sof/d/newport-entry-level-web-developer/7023396802.html
#
# compensation: $15.00/hr to start with 30-Day review
#
# employment type: part-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Local company looking for an Entry Level, full stack web developer to produce scalable software solutions.
#
# Local to RI/MA candidates only. On-prem position only.
#
# The right candidate will join a cross-functional team that’s responsible for the full software development life cycle, from conception to deployment.
#
# The right candidate should be comfortable around both front-end and back-end coding languages, development frameworks and third-party libraries and also be a team player with a capacity for visual design and utility.
#
# Responsibilities
# - Design client-side and server-side architecture
# - Build the front-end of applications through appealing visual design
# - Develop and manage well-functioning databases and applications
# - Write effective REST APIs
# - Test software to ensure responsiveness and efficiency
# - Troubleshoot, debug and upgrade software
# - Create security and data protection settings
# - Build features and applications with a mobile responsive design
# - Write technical documentation
#
# Requirements
#
# - Proven experience as a full stack web developer or similar role
# - Familiarity with common web technologies
# - Experience with multiple front-end languages and libraries (e.g. HTML/ CSS, JavaScript, XML, jQuery)
# - Experience with Wordpress and Magento CMS Platforms
# - Experience with multiple back-end languages (e.g. C#, Java, Laravel, Cake PHP) and JavaScript frameworks (e.g. Angular, React, Node.js)
# - Familiarity with databases (e.g. MySQL, MongoDB), web servers (e.g. Apache) and UI/UX design
# - Excellent communication and teamwork skills
# - Great attention to detail
# - Organizational skills
# - An analytical mind
#
# Reply to this posting with your resume. Applications must include a resume from a local-to-RI/MA candidate to be considered.
# On-prem position only.
# ---
# Job Title: Software and Data Engineer (full-stack)
# Location: N/A
# Date: Oct 24
# Link: https://providence.craigslist.org/sof/d/north-kingstown-software-and-data/7006516880.html
#
# compensation: DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Axiom Data Science, LLC
# http://axiomdatascience.com/about/
#
# Title: Software and Data Engineer (full-stack)
#
# Location: North Kingstown, RI
#
# This position may also work from one of our offices in Anchorage, AK; Fairbanks, AK; or Portland, OR, depending on the candidate.
#
# What we do
# Axiom is a small and dynamic (~20 person) technology and informatics firm with a mission to build a better understanding of society and the environment by increasing the accessibility, reuse, and impact of scientific data. To that end, we provide cyberinfrastructure support, data management systems, and scalable solutions for organizing and analyzing large amounts of diverse datasets to organizations across the globe. We’ve assembled an outstanding team of software developers, data analysts, and data coordinators to tackle difficult problems and provide excellent support to our partners at businesses, non-profits, federal and state agencies, and universities. Axiom is headquartered in Anchorage, Alaska and has satellite offices in Portland, Oregon; North Kingstown, Rhode Island; Homer, Alaska; and Fairbanks, Alaska.
#
# How we work
# We are not a consulting firm, we are a mission driven technology partner. We believe in focusing time and energy on our core products, forming mutually beneficial partnerships with clients, and encouraging developers to take ownership of their work.
#
# We are a geographically distributed company and collaborate with each other online. Strong communication skills are critical. We work together closely while minimizing distractions.
#
# We have low administrative overhead. Our employees are given all the tools they need to excel and are self-driven, resourceful, and instrumental in expanding our vision.
#
# We value uptime. Our systems are horizontally scalable and redundant. We care about discovering issues before our users are affected.
#
# What you’ll do
# The Axiom team works to enhance and sustain scientific data by upscaling metadata, semantically linking datasets, developing specialized services, creating powerful visualizations, and applying advanced analysis techniques. As a full-stack software and data engineer you will touch everything from front-end code to our high performance computing infrastructure. You will develop new features and applications as well as support existing applications written by the team. This will include front-end development of web applications, user interfaces, data visualizations, and documented web APIs as well as back-end development of web services, software tools, analysis pipelines/applications, and efficient data storage/access techniques.
#
# What you’ll work with
# Our stack is constantly evolving, with decisions on technologies made by engineers. You’ll work with a wide range of technologies and you are not expected to have experience with all of these technologies from the start; a demonstrated ability to learn new technologies and select appropriate technologies for each solution is more important.
#
#
# Frontend: Backbone, React, Vue, D3
#
# Backend: Java, Python, Node
#
# Storage: PostgreSQL, GlusterFS, Redis, ElasticSearch, MongoDB, TimescaleDB, Kafka
#
# Analysis: Apache Spark, Dask, Numpy, Pandas, scikit-learn, Tensorflow, Keras
#
# DevOps: GitLab (SCM, CI), Docker, Ansible, Prometheus, Fluentd, Grafana, Loki
#
# Specialized: NetCDF, Apache Arrow, GeoServer, OGC standards
#
#
# What we look for
# As above, you are not expected to meet all of the criteria below. A demonstrated history working with and delivering real-world software is key.
#
#
# BS or MS in Computer Science or equivalent experience
#
# Strong experience in full-stack web application development, including database design, architecture, services, and APIs
#
# Experience with modern front-end development and web frameworks
#
# Experience with the data science / scientific Python stack
#
# Experience working as a member of a software engineering team
#
# Experience working with data from the physical or biological sciences
#
# Self-motivation, independence, flexibility, and a problem-solving attitude
#
#
# What you’ll get
# A healthy work/life balance and a competitive salary commensurate with experience. Benefits include 5 weeks paid leave plus holidays, healthcare reimbursement, a company 401K plan, and a gym membership.
#
# How to apply
# Reply to this post with your resume and cover letter by November 15, 2019. Include 'Software and Data Engineer' in the subject line. The following additional application materials are recommended, but not required: code samples, profile links to GitHub/StackOverflow; descriptions and screenshots of a completed project; and other examples of expertise or open source participation.
#
# ---
# Job Title: Python Software Engineer
# Location: N/A
# Date: Nov  8
# Link: https://hartford.craigslist.org/sof/d/hartford-python-software-engineer/7016071955.html
#
# compensation: $45-50K
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Join a small team of engineers at a leading national mobility company that is responsible for maintaining a variety of high-tech products. You will be creating and maintaining back-end applications that are highly visible.
#
# You’ll love this job if you are curious and interested in exploring all aspects of the development lifecycle: planning, development, deployment, and maintenance. You will work directly under the Senior Software Engineer to deliver results in a fast-paced environment.
#
# In addition to a competitive salary, you’ll have the opportunity to be a part of a team that will positively impact the lives of many people daily.  There will be opportunity to grow in the company.
#
# Job Responsibilities:
# •	Maintain and develop various applications for data collection
# •	Consume APIs inside of your own applications effectively
# •	Query and maintain various forms of database—both SQL and No-SQL
# •	Learn new tools and implement them into existing infrastructure efficiently
#
# Job Requirements:
# •	Python
# •	SQL
# •	Linux
# •	General Cloud Platform knowledge (Google Cloud Platform, Amazon Web Services, Azure)
# •	Version control (Git preferred, but any is acceptable)
# •	Self-motivated with the ability to primarily work independently outside of meetings
# •	Communicate effective deliverable dates and execute on them
# •	Ability to analyze problems and solve them quickly and effectively
# •	Excellent interpersonal skills
#
# Nice to Haves:
# •	Docker experience
# •	Working understanding of networking
#
# Recent Computer Science graduate preferred, or equivalent training with demonstrable deployments.  There will be a take home micro-assignment for all interviewees.
#
# If you have a passion to develop software and your experience aligns with this job, come interview with us!
# ---
# Job Title: Node.js Software Engineer
# Location: N/A
# Date: Nov  8
# Link: https://hartford.craigslist.org/sof/d/hartford-nodejs-software-engineer/7016059857.html
#
# compensation: $45-50K DOE
#
# employment type: full-time
#
#
# Job Description:
#
# QR Code Link to This Post
#
#
# Join a small team of engineers at a leading national mobility company that is responsible for maintaining a variety of high-tech products. You will be creating and maintaining back-end applications that are highly visible.
#
# You’ll love this job if you are curious and interested in exploring all aspects of the development lifecycle: planning, development, deployment, and maintenance. You will work directly under the Senior Software Engineer to deliver results in a fast-paced environment.
#
# In addition to a competitive salary, you’ll have the opportunity to be a part of a team that will positively impact the lives of many people daily.  There will be opportunity to grow in the company.
#
# Job Responsibilities:
# •	Maintain and develop various applications for data collection
# •	Consume APIs inside of your own applications effectively
# •	Query and maintain various forms of database—both SQL and No-SQL
# •	Learn new tools and implement them into existing infrastructure efficiently
#
# Job Requirements:
# •	JavaScript / Node.js
# •	SQL
# •	Linux
# •	General Cloud Platform knowledge (Google Cloud Platform, Amazon Web Services, Azure)
# •	Version control (Git preferred, but any is acceptable)
# •	Basic front-end proficiency (HTML, CSS)
# •	Self-motivated with the ability to primarily work independently outside of meetings
# •	Communicate effective deliverable dates and execute on them
# •	Ability to analyze problems and solve them quickly and effectively
# •	Excellent interpersonal skills
#
# Nice to Haves:
# •	Docker experience
# •	Working understanding of networking
#
# Recent Computer Science graduate preferred, or equivalent training with demonstrable deployments.  There will be a take home micro-assignment for all interviewees.
#
# If you have a passion to develop software and your experience aligns with this job, come interview with us!
#
# ---
# Total Jobs: 42

# %% [markdown]
# #create a dictonary

# %%
# Create a dictionary
d = {'key':'value'}
print(d)


# Update the dictionary
d['new key'] = 'new value'
print(d)


npo_jobs = {}
job_no = 0
while True:
    
    response = requests.get(url)
    data = response.text
    soup = BeautifulSoup(data,'html.parser')
    jobs = soup.find_all('p',{'class':'result-info'})
    
    for job in jobs:
        
        title = job.find('a',{'class':'result-title'}).text
        location_tag = job.find('span',{'class':'result-hood'})
        location = location_tag.text[2:-1] if location_tag else "N/A"
        date = job.find('time', {'class': 'result-date'}).text
        link = job.find('a', {'class': 'result-title'}).get('href')
        
        job_response = requests.get(link)
        job_data = job_response.text
        job_soup = BeautifulSoup(job_data, 'html.parser')
        job_description = job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag = job_soup.find('p',{'class':'attrgroup'})
        job_attributes = job_attributes_tag.text if job_attributes_tag else "N/A"
        
        job_no+=1
        npo_jobs[job_no] = [title, location, date, link, job_attributes, job_description]
        
        
#       print('Job Title:', title, '\nLocation:', location, '\nDate:', date, '\nLink:', link,"\n", job_attributes, '\nJob Description:', job_description,'\n---')
        
    url_tag = soup.find('a',{'title':'next page'})
    if url_tag.get('href'):
        url= 'https://boston.craigslist.org' + url_tag.get('href')
        print(url)
    else:
        break
        
print("Total Jobs:", job_no)
npo_jobs_df = pd.DataFrame.from_dict(npo_jobs, orient = 'index', columns = ['Job Title','Location','Date', 'Link', 'Job Attributes', 'Job Description'])


npo_jobs_df.head()


npo_jobs_df.to_csv('npo_jobs.csv')
# Out:
# {'key': 'value'}
# {'key': 'value', 'new key': 'new value'}
# Total Jobs: 42
